# %%
# %matplotlib inline
mpl.rcParams['figure.figsize'] = (20, 4)
mpl.rcParams['axes.grid'] = False

from scipy import stats

# %% [markdown]
# action_steps = 83
# freq = 15
# policy_freq =
# simulation_steps = action_steps * freq
# simulation_steps

# %%
def plot(x,y):
    _ = plt.plot(x,y)
    _ = plt.xlabel('steps')
    _ = plt.ylabel('demand (veh/hr)')

# %%
def generate_demand(max_demand=15000, periods=2, steps=100, simulation_freq=15):
    simulation_steps = steps * simulation_freq
    x = np.linspace(0, periods * 2 * np.pi, simulation_steps)
    y1 = ((np.sin(x) + 1) / 2) * max_demand
    y2 = max_demand - y1
    
    return y1, y2

# %%
y1, y2 = generate_demand(periods=3)
x = np.arange(len(y1))
_ = plt.plot(x,y1)
_ = plt.plot(x,y2)
_ = plt.xlabel('steps')
_ = plt.ylabel('demand (veh/hr)')
_ = plt.show()

# %%
AMPLITUDE = np.random.normal(10000, 2000)
PERIODS = np.abs(np.random.normal(2,1))
x = np.linspace(0, PERIODS * (2*np.pi), simulation_steps)
y1 = np.random.normal(0.5, 0.1) * (np.sin(x) + np.random.normal(2, 0.2)) * AMPLITUDE
y2 = np.min(y1) + (np.max(y1) - y1)

plot(x,y1)
plot(x,y2)

# %%
y = np.random.uniform(1000, 20000, 6000)

# %%
x = range(6000)
y = np.random.poisson(1, 6000) * 3600
y1 = pd.Series(y).rolling(30).mean().plot()

# %%
x = np.arange(3000)

y1 = pd.Series(np.random.uniform(2000, 16000, 100)).repeat(30)
y2 = pd.Series(np.random.uniform(2000, 16000, 100)).repeat(30)

# %%
x = np.arange(3000)

y1 = pd.Series(np.random.normal(10000, 3000, 100)).repeat(30)
y2 = pd.Series(np.random.normal(10000, 3000, 100)).repeat(30)

# %%
plt.plot(x,y1)
plt.plot(x,y2)

# %%
periods = 1
amp = 15000
steps = 3000
x = np.linspace(0, periods * 2 * np.pi, steps)

y1 = ((np.sin(x) + 1) / 2) * amp
#y2 = amp - y1

plt.plot(y1);

# %%
plt.hist(np.random.normal(2000, 1000, 3000))
# Out:
# (array([ 12.,  55., 220., 511., 719., 755., 472., 195.,  52.,   9.]),
#  array([-1285.44568085,  -629.18843044,    27.06881997,   683.32607038,
#          1339.58332079,  1995.8405712 ,  2652.09782162,  3308.35507203,
#          3964.61232244,  4620.86957285,  5277.12682326]),
#  <BarContainer object of 10 artists>)

# %%
y.shape
# Out:
# (6000,)

# %%
demand_up = np.random.poisson(2.67, 6000)

# %%
sum(demand_up)
# Out:
# 15947

# %%
demand_up[:10]
# Out:
# array([1, 2, 2, 4, 3, 2, 3, 1, 1, 2])
