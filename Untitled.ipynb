# %%
df = pd.read_csv('baseline1.csv')
df.head()
# Out:
#    step  action  upstream_demand  downstream_demand  upstream_flow  \
# 0     1       1      5314.161763        4685.838237            0.0
# 1     2       1      5627.082019        4372.917981         1440.0
# 2     3       1      5937.524167        4062.475833         1440.0
# 3     4       1      6244.261398        3755.738602         1440.0
# 4     5       1      6546.081546        3453.918454         1440.0
#
#    downstream_flow  upstream_speed  downstream_speed  upstream_density  \
# 0              0.0        0.000000          0.998303          0.000000
# 1           2880.0        0.996806          0.984934          0.007143
# 2           1440.0        0.991001          0.913713          0.014286
# 3              0.0        0.985821          0.882294          0.017857
# 4            720.0        0.955898          0.893630          0.025000
#
#    downstream_density
# 0            0.003571
# 1            0.010714
# 2            0.014286
# 3            0.017857
# ...

# %%
df[['upstream_demand', 'downstream_demand']].plot(figsize=(18,3));
df[['upstream_flow', 'downstream_flow']].plot(figsize=(18,3));
df[['upstream_speed', 'downstream_speed']].plot(figsize=(18,3));
df[['upstream_density', 'downstream_density']].plot(figsize=(18,3));
